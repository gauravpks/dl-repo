# %% [markdown]
# <a href="https://colab.research.google.com/github/gauravpks/dl-repo/blob/master/CNN/CNNIntro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://en.wikipedia.org/wiki/Visual_cortex

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Each layer is a Filter..**

# %% [markdown]
# #Convolution

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Blurring**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Edge Detection**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Operation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Instead of (-) we are using.. +... but this is how.. it works.. and it does not make issue.. as gradient decent.. adjusts.. it

# %% [markdown]
# #Padding

# %% [markdown]
# #Pooling

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Max Pooling & Avg Pooling.. Max Pooling is used Mainly**

# %% [markdown]
# ##Max Pooling

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Avg Pooling

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Why Use Pooling**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Different Pool Size

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Why Convolution is followed by Pooling?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Starts looking for basic stokes... and gradually looks for more complex pattern**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Mode

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Convolution in Color Image

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Summery**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Feature Map / Channels

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Convolution Layer

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Batch Normalization

# %% [markdown]
# This is used a lot of Convolution and less with dense layer

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##CNN Architecture

# %% [markdown]
# ![image.png](data:image/png;base64,...)
