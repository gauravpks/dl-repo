# %% [markdown]
# <a href="https://colab.research.google.com/github/gauravpks/dl-repo/blob/master/CNN/StandardCNNnTL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Standard CNN Architecture

# %% [markdown]
# https://medium.com/analytics-vidhya/cnns-architectures-lenet-alexnet-vgg-googlenet-resnet-and-more-666091488df5

# %% [markdown]
# ##LeNet-5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# http://yann.lecun.com/exdb/lenet/index.html

# %% [markdown]
# Sample Code - https://medium.com/@mgazar/lenet-5-in-9-lines-of-code-using-keras-ac99294c8086

# %% [markdown]
# ##AlexNet

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# First to do.. to reduce overfitting
# 1. Data Augumentation
# 2. Stack Convolution Layer Directly on top of each other without pooling
# 3. Applied Dropout with 50% Dropout rate betweem F8 and F9
#
# Trained for 6 days in 2 NVIDIA GTX Systems

# %% [markdown]
# ##Inception - GoogleNet

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##VGGNet

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##RESNet

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Transfer Learning

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Data Handling

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Approach to Transfer Learning

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Problem with Data Augumentation??**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
