# %% [markdown]
# <a href="https://colab.research.google.com/github/gauravpks/dl-repo/blob/master/RNN/SequenceData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Time Series

# %% [markdown]
# **Stock Price**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Airline Demand Forcasting**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Weather Tracking**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Audio/Speech**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Text**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Problem with Bag of Words**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is a sequence??**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Shape of Sequence**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Variable Length Sequence**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
